# %% [markdown]
# # BlazingContext API

# %%
from blazingsql import BlazingContext
# start up BlazingSQL
bc = BlazingContext(pool=False)
# Out:
# BlazingContext ready

# %% [markdown]
# ## Create tables
#
# [Docs](https://docs.blazingdb.com/docs/text-files) | [Welcome notebook](../welcome.ipynb#BlazingContext-API)
#
# BlazingSQL requires the full path to your data to create tables. The next cell will identify the path to the data directory for you.

# %%
import os
# tag path to data directory
data_dir = f"{os.getcwd().split('/intro_notebooks')[0]}/data"

# %%
# create table from CSV
bc.create_table('iris_csv', f'{data_dir}/iris.csv', header=0)

# %%
import cudf

# create cuDF DataFrame
gdf = cudf.read_csv()

# create table from cuDF DataFrame
bc.create_table('cudf_iris')

# %% [markdown]
# ## Query tables
#
# [Docs](https://docs.blazingdb.com/docs/single-gpu) | [Welcome notebook](../welcome.ipynb#BlazingContext-API)

# %%
bc.sql('select * from taxi').head(2)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25           0.0
# 1         14.5    0.5      0.5        2.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80

# %%
bc.sql("SELECT * FROM taxi WHERE tpep_pickup_datetime LIKE '2015-01-15%'")
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0              2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1              2  2015-01-15 19:05:39   2015-01-15 19:32:00                1
# 2              2  2015-01-15 19:05:40   2015-01-15 19:21:00                5
# 3              2  2015-01-15 19:05:40   2015-01-15 19:28:18                5
# 4              2  2015-01-15 19:05:41   2015-01-15 19:20:36                1
# ...          ...                  ...                   ...              ...
# 451181         2  2015-01-15 19:00:45   2015-01-15 19:19:02                1
# 451182         2  2015-01-15 19:00:45   2015-01-15 19:03:17                5
# 451183         2  2015-01-15 19:00:45   2015-01-15 19:18:27                2
# 451184         2  2015-01-15 19:00:45   2015-01-15 19:04:02                5
# 451185         2  2015-01-15 19:00:46   2015-01-15 19:04:24                1
#
#         trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0                1.59        -73.993896        40.750111           1
# 1                2.38        -73.976425        40.739811           1
# 2                2.83        -73.968704        40.754246           1
# 3                8.33        -73.863060        40.769581           1
# 4                2.37        -73.945541        40.779423           1
# ...               ...               ...              ...         ...
# 451181           3.21        -73.995590        40.723045           1
# 451182           0.59        -73.989899        40.767448           1
# 451183           3.68        -73.980698        40.782780           1
# 451184           0.57        -73.973801        40.791424           1
# 451185           0.90        -73.949677        40.780552           1
#
#        store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                       N         -73.974785         40.750618             1
# 1                       N         -73.983978         40.757889             1
# 2                       N         -73.955124         40.786858             2
# 3                       N         -73.952713         40.785782             1
# 4                       N         -73.980850         40.786083             1
# ...                   ...                ...               ...           ...
# 451181                  N         -73.963486         40.716743             1
# 451182                  N         -73.984169         40.773830             1
# 451183                  N         -73.939438         40.805222             1
# 451184                  N         -73.979927         40.786140             2
# 451185                  N         -73.949448         40.787670             2
#
#         fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              12.0    1.0      0.5        3.25          0.00
# 1              16.5    1.0      0.5        4.38          0.00
# 2              12.5    1.0      0.5        0.00          0.00
# 3              26.0    1.0      0.5        8.08          5.33
# 4              11.5    1.0      0.5        0.00          0.00
# ...             ...    ...      ...         ...           ...
# 451181         15.0    1.0      0.5        3.20          0.00
# 451182          4.0    1.0      0.5        1.00          0.00
# 451183         15.0    1.0      0.5        3.20          0.00
# 451184          4.5    1.0      0.5        0.00          0.00
# 451185          5.0    1.0      0.5        0.00          0.00
#
#         improvement_surcharge  total_amount
# 0                         0.3         17.05
# 1                         0.3         22.68
# 2                         0.3         14.30
# 3                         0.3         41.21
# 4                         0.3         13.30
# ...                       ...           ...
# 451181                    0.3         20.00
# 451182                    0.3          6.80
# 451183                    0.3         20.00
# 451184                    0.3          6.30
# 451185                    0.3          6.80
#
# [451186 rows x 19 columns]

# %%
# pull rides Jan 15 - Jan 20
bc.sql("select * from taxi where tpep_pickup_datetime BETWEEN '2015-01-15' AND '2015-01-20'")
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1               2  2015-01-15 19:05:39   2015-01-15 19:32:00                1
# 2               2  2015-01-15 19:05:40   2015-01-15 19:21:00                5
# 3               2  2015-01-15 19:05:40   2015-01-15 19:28:18                5
# 4               2  2015-01-15 19:05:41   2015-01-15 19:20:36                1
# ...           ...                  ...                   ...              ...
# 2175969         2  2015-01-16 21:48:16   2015-01-16 21:56:52                1
# 2175970         2  2015-01-16 21:48:16   2015-01-16 21:57:32                1
# 2175971         2  2015-01-16 21:48:16   2015-01-16 21:56:19                6
# 2175972         2  2015-01-16 21:48:16   2015-01-16 21:52:19                1
# 2175973         2  2015-01-16 21:48:17   2015-01-16 21:55:51                5
#
#          trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0                 1.59        -73.993896        40.750111           1
# 1                 2.38        -73.976425        40.739811           1
# 2                 2.83        -73.968704        40.754246           1
# 3                 8.33        -73.863060        40.769581           1
# 4                 2.37        -73.945541        40.779423           1
# ...                ...               ...              ...         ...
# 2175969           1.86        -73.991241        40.774784           1
# 2175970           2.25        -73.976631        40.775311           1
# 2175971           4.01        -73.975975        40.744953           1
# 2175972           0.98        -73.970444        40.789043           1
# 2175973           1.39        -73.978645        40.764198           1
#
#         store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                        N         -73.974785         40.750618             1
# 1                        N         -73.983978         40.757889             1
# 2                        N         -73.955124         40.786858             2
# 3                        N         -73.952713         40.785782             1
# 4                        N         -73.980850         40.786083             1
# ...                    ...                ...               ...           ...
# 2175969                  N         -73.969238         40.761181             2
# 2175970                  N         -73.951202         40.786060             1
# 2175971                  N         -74.002205         40.709129             2
# 2175972                  N         -73.979385         40.776642             2
# 2175973                  N         -73.985077         40.747952             2
#
#          fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0               12.0    1.0      0.5        3.25          0.00
# 1               16.5    1.0      0.5        4.38          0.00
# 2               12.5    1.0      0.5        0.00          0.00
# 3               26.0    1.0      0.5        8.08          5.33
# 4               11.5    1.0      0.5        0.00          0.00
# ...              ...    ...      ...         ...           ...
# 2175969          8.5    0.5      0.5        0.00          0.00
# 2175970          9.5    0.5      0.5        1.00          0.00
# 2175971         13.0    0.5      0.5        0.00          0.00
# 2175972          5.0    0.5      0.5        0.00          0.00
# 2175973          7.0    0.5      0.5        0.00          0.00
#
#          improvement_surcharge  total_amount
# 0                          0.3         17.05
# 1                          0.3         22.68
# 2                          0.3         14.30
# 3                          0.3         41.21
# 4                          0.3         13.30
# ...                        ...           ...
# 2175969                    0.3          9.80
# 2175970                    0.3         11.80
# 2175971                    0.3         14.30
# 2175972                    0.3          6.30
# 2175973                    0.3          8.30
#
# [2175974 rows x 19 columns]
