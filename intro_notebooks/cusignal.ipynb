# %% [markdown]
# ### cuSignal
#
# The RAPIDS cuSignal project leverages CuPy, Numba, and the RAPIDS ecosystem for GPU accelerated signal processing.
#
# In some cases, cuSignal is a direct port of Scipy Signal to leverage GPU compute resources via CuPy but also contains Numba CUDA kernels for additional speedups for selected functions.
#
# cuSignal achieves its best gains on large signals and compute intensive functions but stresses online processing with zero-copy memory (pinned, mapped) between CPU and GPU.
#
# [GitHub](https://github.com/rapidsai/cusignal) | [Welcome notebook](../welcome.ipynb#cuSignal---GPU-Accelerated-Signal-Processing)

# %%
from blazingsql import BlazingContext

# connect to BlazingSQL w/ BlazingContext API
bc = BlazingContext(pool=False)
# Out:
# BlazingContext ready

# %%
import os

# BlazingContext requires full data path
data_path = f'{os.getcwd().split("/intro_notebooks")[0]}/data/sample_taxi.csv'

# what's the data's path?
print(f"data_path == '{data_path}'\n")

# create a BlazingSQL table from any file w/ .create_table(table_name, file_path)
bc.create_table('taxi', data_path, header=0)
# Out:
# data_path == '/jupyterhub-homes/winston@blazingdb.com/bsql-demos/welcome_notebooks/data/sample_taxi.csv'

# %%
taxi_columns = [col for col in bc.sql('select * from taxi').columns if col not in ['fare_amount', 'total_amount']]

taxi_columns
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'payment_type',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'pickup_x',
#  'pickup_y',
#  'dropoff_x',
#  'dropoff_y']

# %%
from cuml.preprocessing.model_selection import train_test_split

# split data into training & testing sets (70:30)
X_train, X_test, y_train, y_test = train_test_split(bc.sql('SELECT ', y, train_size = 0.7))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f730cb1eef56> in <module>
#       2
#       3 # split data into training & testing sets (70:30)
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(bc.sql('SELECT ', y, train_size = 0.7))
#
# NameError: name 'y' is not defined

# %%
# convert cuDF DataFrame to pandas to identify feature correlation 
corr = bc.sql('select * from taxi').to_pandas().corr()

# visualize correlations
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col1 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col4 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col5 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col6 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col7 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col8 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col10 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col11 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col13 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col14 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow0_col15 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col0 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col3 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col4 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col6 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col7 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col8 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col10 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col11 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col12 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col13 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col14 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow1_col15 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col0 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col3 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col6 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col8 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col10 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col11 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col12 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col13 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col14 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow2_col15 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col8 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col9 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col10 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_322ea608_6874_11ea_8baa_0a2a0761941drow3_col11 {
#             background-color:  #84a7fc;
