# %% [markdown]
# # BlazingSQL Cheat Sheets sample code
#
# (c) 2020 NVIDIA, Blazing SQL
#
# Distributed under Apache License 2.0

# %% [markdown]
# ### Imports

# %%
import cudf
import numpy as np
from blazingsql import BlazingContext

# %% [markdown]
# ### Sample Data Table

# %%
df = cudf.DataFrame(
    [
          (39, 6.88, np.datetime64('2020-10-08T12:12:01'), 'C', 'D', 'data'
            , 'RAPIDS.ai is a suite of open-source libraries that allow you to run your end to end data science and analytics pipelines on GPUs.')
        , (11, 4.21, None,                                 'A', 'D', 'cuDF'
            , 'cuDF is a Python GPU DataFrame (built on the Apache Arrow columnar memory format)')
        , (31, 4.71, np.datetime64('2020-10-10T09:26:43'), 'U', 'D', 'memory'
            , 'cuDF allows for loading, joining, aggregating, filtering, and otherwise manipulating tabular data using a DataFrame style API.')
        , (40, 0.93, np.datetime64('2020-10-11T17:10:00'), 'P', 'B', 'tabular'
            , '''If your workflow is fast enough on a single GPU or your data comfortably fits in memory on 
                 a single GPU, you would want to use cuDF.''')
        , (33, 9.26, np.datetime64('2020-10-15T10:58:02'), 'O', 'D', 'parallel'
            , '''If you want to distribute your workflow across multiple GPUs or have more data than you can fit 
                 in memory on a single GPU you would want to use Dask-cuDF''')
        , (42, 4.21, np.datetime64('2020-10-01T10:02:23'), 'U', 'C', 'GPUs'
            , 'BlazingSQL provides a high-performance distributed SQL engine in Python')
        , (36, 3.01, np.datetime64('2020-09-30T14:36:26'), 'T', 'D', None
            , 'BlazingSQL is built on the RAPIDS GPU data science ecosystem')
        , (38, 6.44, np.datetime64('2020-10-10T08:34:36'), 'X', 'B', 'csv'
            , 'BlazingSQL lets you ETL raw data directly into GPU memory as a GPU DataFrame (GDF)')
        , (17, 5.28, np.datetime64('2020-10-09T08:34:40'), 'P', 'D', 'dataframes'
            , 'Dask is a flexible library for parallel computing in Python')
        , (10, 8.28, np.datetime64('2020-10-03T03:31:21'), 'W', 'B', 'python'
            , None)
    ]
    , columns = ['number', 'float_number', 'datetime', 'letter', 'category', 'word', 'string']
)

# %%
df_join = cudf.DataFrame({
    'cat': ['B', 'C', 'V']
    , 'means': [23.4, 71.4, 823.2]
})

# %%
bc = BlazingContext()
# Out:
# BlazingContext ready

# %%
bc.create_table('df', df)
bc.create_table('df2', df_join)

# %% [markdown]
# # SQL Joins

# %%
query = '''
    SELECT A.category
        , B.means
        , SUM(A.number) AS number_sum
        , AVG(A.increased) AS increased_avg
    FROM (
        SELECT category
            , number
            , float_number + 3.12 AS increased
        FROM df
        WHERE float_number > 0.93
    ) AS A
    INNER JOIN df2 AS B
        ON A.category = B.cat
    GROUP BY A.category
        , B.means
    ORDER BY category
'''

bc.sql(query)
# Out:
#   category  means  number_sum  increased_avg
# 0        B   23.4          48          10.48
# 1        C   71.4          42           7.33

# %% [markdown]
# #### INNER

# %%
query = '''
    SELECT *
    FROM df AS A
    INNER JOIN df2 AS B
        ON A.category = B.cat
'''

bc.sql(query)
# Out:
#    number  float_number            datetime letter category     word  \
# 0      40          0.93 2020-10-11 17:10:00      P        B  tabular
# 1      42          4.21 2020-10-01 10:02:23      U        C     GPUs
# 2      38          6.44 2020-10-10 08:34:36      X        B      csv
# 3      10          8.28 2020-10-03 03:31:21      W        B   python
#
#                                               string cat  means
# 0  If your workflow is fast enough on a single GP...   B   23.4
# 1  BlazingSQL provides a high-performance distrib...   C   71.4
# 2  BlazingSQL lets you ETL raw data directly into...   B   23.4
# 3                                               <NA>   B   23.4

# %%
query = '''
    SELECT *
    FROM df
    INNER JOIN df2
        ON df.category = df2.cat
'''

bc.sql(query)
# Out:
#    number  float_number            datetime letter category     word  \
# 0      40          0.93 2020-10-11 17:10:00      P        B  tabular
# 1      42          4.21 2020-10-01 10:02:23      U        C     GPUs
# 2      38          6.44 2020-10-10 08:34:36      X        B      csv
# 3      10          8.28 2020-10-03 03:31:21      W        B   python
#
#                                               string cat  means
# 0  If your workflow is fast enough on a single GP...   B   23.4
# 1  BlazingSQL provides a high-performance distrib...   C   71.4
# 2  BlazingSQL lets you ETL raw data directly into...   B   23.4
# 3                                               <NA>   B   23.4

# %% [markdown]
# #### FULL OUTER

# %%
query = '''
    SELECT *
    FROM df
    FULL OUTER JOIN df2
        ON df.category = df2.cat
'''

bc.sql(query)
# Out:
#    number float_number             datetime letter category        word  \
# 0    <NA>         <NA>                 <NA>   <NA>     <NA>        <NA>
# 1      40         0.93  2020-10-11 17:10:00      P        B     tabular
# 2      42         4.21  2020-10-01 10:02:23      U        C        GPUs
# 3      38         6.44  2020-10-10 08:34:36      X        B         csv
# 4      10         8.28  2020-10-03 03:31:21      W        B      python
# 5      39         6.88  2020-10-08 12:12:01      C        D        data
# 6      11         4.21                 <NA>      A        D        cuDF
# 7      31         4.71  2020-10-10 09:26:43      U        D      memory
# 8      33         9.26  2020-10-15 10:58:02      O        D    parallel
# 9      36         3.01  2020-09-30 14:36:26      T        D        <NA>
# 10     17         5.28  2020-10-09 08:34:40      P        D  dataframes
#
#                                                string   cat  means
# 0                                                <NA>     V  823.2
# 1   If your workflow is fast enough on a single GP...     B   23.4
# 2   BlazingSQL provides a high-performance distrib...     C   71.4
# 3   BlazingSQL lets you ETL raw data directly into...     B   23.4
# 4                                                <NA>     B   23.4
# 5   RAPIDS.ai is a suite of open-source libraries ...  <NA>   <NA>
# 6   cuDF is a Python GPU DataFrame (built on the A...  <NA>   <NA>
# 7   cuDF allows for loading, joining, aggregating,...  <NA>   <NA>
# 8   If you want to distribute your workflow across...  <NA>   <NA>
# 9   BlazingSQL is built on the RAPIDS GPU data sci...  <NA>   <NA>
# 10  Dask is a flexible library for parallel comput...  <NA>   <NA>

# %% [markdown]
# #### LEFT OUTER

# %%
query = '''
    SELECT *
    FROM df
    LEFT JOIN df2
        ON df.category = df2.cat
'''

bc.sql(query)
# Out:
#    number  float_number             datetime letter category        word  \
# 0      40          0.93  2020-10-11 17:10:00      P        B     tabular
# 1      42          4.21  2020-10-01 10:02:23      U        C        GPUs
# 2      38          6.44  2020-10-10 08:34:36      X        B         csv
# 3      10          8.28  2020-10-03 03:31:21      W        B      python
# 4      39          6.88  2020-10-08 12:12:01      C        D        data
# 5      11          4.21                 <NA>      A        D        cuDF
# 6      31          4.71  2020-10-10 09:26:43      U        D      memory
# 7      33          9.26  2020-10-15 10:58:02      O        D    parallel
# 8      36          3.01  2020-09-30 14:36:26      T        D        <NA>
# 9      17          5.28  2020-10-09 08:34:40      P        D  dataframes
#
#                                               string   cat means
# 0  If your workflow is fast enough on a single GP...     B  23.4
# 1  BlazingSQL provides a high-performance distrib...     C  71.4
# 2  BlazingSQL lets you ETL raw data directly into...     B  23.4
# 3                                               <NA>     B  23.4
# 4  RAPIDS.ai is a suite of open-source libraries ...  <NA>  <NA>
# 5  cuDF is a Python GPU DataFrame (built on the A...  <NA>  <NA>
# 6  cuDF allows for loading, joining, aggregating,...  <NA>  <NA>
# 7  If you want to distribute your workflow across...  <NA>  <NA>
# 8  BlazingSQL is built on the RAPIDS GPU data sci...  <NA>  <NA>
# 9  Dask is a flexible library for parallel comput...  <NA>  <NA>

# %%
query = '''
    SELECT *
    FROM df2
    LEFT JOIN df
        ON df.category = df2.cat
'''

bc.sql(query)
# Out:
#   cat  means number float_number             datetime letter category  \
# 0   B   23.4     40         0.93  2020-10-11 17:10:00      P        B
# 1   C   71.4     42         4.21  2020-10-01 10:02:23      U        C
# 2   V  823.2   <NA>         <NA>                 <NA>   <NA>     <NA>
# 3   B   23.4     38         6.44  2020-10-10 08:34:36      X        B
# 4   B   23.4     10         8.28  2020-10-03 03:31:21      W        B
#
#       word                                             string
# 0  tabular  If your workflow is fast enough on a single GP...
# 1     GPUs  BlazingSQL provides a high-performance distrib...
# 2     <NA>                                               <NA>
# 3      csv  BlazingSQL lets you ETL raw data directly into...
# 4   python                                               <NA>

# %% [markdown]
# #### CROSS JOIN

# %%
query = '''
    SELECT *
    FROM df
    CROSS JOIN df2
'''

bc.sql(query)
# Out:
#     number  float_number             datetime letter category        word  \
# 0       39          6.88  2020-10-08 12:12:01      C        D        data
# 1       39          6.88  2020-10-08 12:12:01      C        D        data
# 2       39          6.88  2020-10-08 12:12:01      C        D        data
# 3       11          4.21                 <NA>      A        D        cuDF
# 4       11          4.21                 <NA>      A        D        cuDF
# 5       11          4.21                 <NA>      A        D        cuDF
# 6       31          4.71  2020-10-10 09:26:43      U        D      memory
# 7       31          4.71  2020-10-10 09:26:43      U        D      memory
# 8       31          4.71  2020-10-10 09:26:43      U        D      memory
# 9       40          0.93  2020-10-11 17:10:00      P        B     tabular
# 10      40          0.93  2020-10-11 17:10:00      P        B     tabular
# 11      40          0.93  2020-10-11 17:10:00      P        B     tabular
# 12      33          9.26  2020-10-15 10:58:02      O        D    parallel
# 13      33          9.26  2020-10-15 10:58:02      O        D    parallel
# 14      33          9.26  2020-10-15 10:58:02      O        D    parallel
# 15      42          4.21  2020-10-01 10:02:23      U        C        GPUs
# 16      42          4.21  2020-10-01 10:02:23      U        C        GPUs
# 17      42          4.21  2020-10-01 10:02:23      U        C        GPUs
# 18      36          3.01  2020-09-30 14:36:26      T        D        <NA>
# 19      36          3.01  2020-09-30 14:36:26      T        D        <NA>
# 20      36          3.01  2020-09-30 14:36:26      T        D        <NA>
# 21      38          6.44  2020-10-10 08:34:36      X        B         csv
# 22      38          6.44  2020-10-10 08:34:36      X        B         csv
# 23      38          6.44  2020-10-10 08:34:36      X        B         csv
# 24      17          5.28  2020-10-09 08:34:40      P        D  dataframes
# 25      17          5.28  2020-10-09 08:34:40      P        D  dataframes
# 26      17          5.28  2020-10-09 08:34:40      P        D  dataframes
# 27      10          8.28  2020-10-03 03:31:21      W        B      python
# 28      10          8.28  2020-10-03 03:31:21      W        B      python
# 29      10          8.28  2020-10-03 03:31:21      W        B      python
#
#                                                string cat  means
# 0   RAPIDS.ai is a suite of open-source libraries ...   B   23.4
# 1   RAPIDS.ai is a suite of open-source libraries ...   C   71.4
# 2   RAPIDS.ai is a suite of open-source libraries ...   V  823.2
# 3   cuDF is a Python GPU DataFrame (built on the A...   B   23.4
# 4   cuDF is a Python GPU DataFrame (built on the A...   C   71.4
# 5   cuDF is a Python GPU DataFrame (built on the A...   V  823.2
# 6   cuDF allows for loading, joining, aggregating,...   B   23.4
# 7   cuDF allows for loading, joining, aggregating,...   C   71.4
# 8   cuDF allows for loading, joining, aggregating,...   V  823.2
# 9   If your workflow is fast enough on a single GP...   B   23.4
# 10  If your workflow is fast enough on a single GP...   C   71.4
# 11  If your workflow is fast enough on a single GP...   V  823.2
# 12  If you want to distribute your workflow across...   B   23.4
# 13  If you want to distribute your workflow across...   C   71.4
# 14  If you want to distribute your workflow across...   V  823.2
# 15  BlazingSQL provides a high-performance distrib...   B   23.4
# 16  BlazingSQL provides a high-performance distrib...   C   71.4
# 17  BlazingSQL provides a high-performance distrib...   V  823.2
# 18  BlazingSQL is built on the RAPIDS GPU data sci...   B   23.4
# 19  BlazingSQL is built on the RAPIDS GPU data sci...   C   71.4
# 20  BlazingSQL is built on the RAPIDS GPU data sci...   V  823.2
# 21  BlazingSQL lets you ETL raw data directly into...   B   23.4
# 22  BlazingSQL lets you ETL raw data directly into...   C   71.4
# 23  BlazingSQL lets you ETL raw data directly into...   V  823.2
# 24  Dask is a flexible library for parallel comput...   B   23.4
# 25  Dask is a flexible library for parallel comput...   C   71.4
# 26  Dask is a flexible library for parallel comput...   V  823.2
# 27                                               <NA>   B   23.4
# 28                                               <NA>   C   71.4
# 29                                               <NA>   V  823.2
