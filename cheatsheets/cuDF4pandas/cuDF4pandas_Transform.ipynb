# %% [markdown]
# # cuDF Cheat Sheets sample code
#
# (c) 2020 NVIDIA, Blazing SQL
#
# Distributed under Apache License 2.0

# %% [markdown]
# ### Imports

# %%
import cudf
import pandas as pd
import numpy as np

# %% [markdown]
# ### Sample DataFrame

# %%
# pandas
pandas_df = pd.DataFrame(
    [
          (39, 6.88, np.datetime64('2020-10-08T12:12:01'), np.timedelta64(14378,'s'), 'C', 'D', 'data'
            , 'RAPIDS.ai is a suite of open-source libraries that allow you to run your end to end data science and analytics pipelines on GPUs.')
        , (11, 4.21, None,                                 None                     , 'A', 'D', 'cuDF'
            , 'cuDF is a Python GPU DataFrame (built on the Apache Arrow columnar memory format)')
        , (31, 4.71, np.datetime64('2020-10-10T09:26:43'), np.timedelta64(12909,'s'), 'U', 'D', 'memory'
            , 'cuDF allows for loading, joining, aggregating, filtering, and otherwise manipulating tabular data using a DataFrame style API.')
        , (40, 0.93, np.datetime64('2020-10-11T17:10:00'), np.timedelta64(10466,'s'), 'P', 'B', 'tabular'
            , '''If your workflow is fast enough on a single GPU or your data comfortably fits in memory on 
                 a single GPU, you would want to use cuDF.''')
        , (33, 9.26, np.datetime64('2020-10-15T10:58:02'), np.timedelta64(35558,'s'), 'O', 'D', 'parallel'
            , '''If you want to distribute your workflow across multiple GPUs or have more data than you can fit 
                 in memory on a single GPU you would want to use Dask-cuDF''')
        , (42, 4.21, np.datetime64('2020-10-01T10:02:23'), np.timedelta64(20480,'s'), 'U', 'C', 'GPUs'
            , 'BlazingSQL provides a high-performance distributed SQL engine in Python')
        , (36, 3.01, np.datetime64('2020-09-30T14:36:26'), np.timedelta64(24409,'s'), 'T', 'D', None
            , 'BlazingSQL is built on the RAPIDS GPU data science ecosystem')
        , (38, 6.44, np.datetime64('2020-10-10T08:34:36'), np.timedelta64(90171,'s'), 'X', 'B', 'csv'
            , 'BlazingSQL lets you ETL raw data directly into GPU memory as a GPU DataFrame (GDF)')
        , (17, 5.28, np.datetime64('2020-10-09T08:34:40'), np.timedelta64(30532,'s'), 'P', 'D', 'dataframes'
            , 'Dask is a flexible library for parallel computing in Python')
        , (10, 8.28, np.datetime64('2020-10-03T03:31:21'), np.timedelta64(23552,'s'), 'W', 'B', 'python'
            , None)
    ]
    , columns = ['num', 'float', 'datetime', 'timedelta', 'char', 'category', 'word', 'string']
)
pandas_df['category'] = pandas_df['category'].astype('category')

# %%
# cudf
cudf_df = cudf.DataFrame(
    [
          (39, 6.88, np.datetime64('2020-10-08T12:12:01'), np.timedelta64(14378,'s'), 'C', 'D', 'data'
            , 'RAPIDS.ai is a suite of open-source libraries that allow you to run your end to end data science and analytics pipelines on GPUs.')
        , (11, 4.21, None,                                 None                     , 'A', 'D', 'cuDF'
            , 'cuDF is a Python GPU DataFrame (built on the Apache Arrow columnar memory format)')
        , (31, 4.71, np.datetime64('2020-10-10T09:26:43'), np.timedelta64(12909,'s'), 'U', 'D', 'memory'
            , 'cuDF allows for loading, joining, aggregating, filtering, and otherwise manipulating tabular data using a DataFrame style API.')
        , (40, 0.93, np.datetime64('2020-10-11T17:10:00'), np.timedelta64(10466,'s'), 'P', 'B', 'tabular'
            , '''If your workflow is fast enough on a single GPU or your data comfortably fits in memory on 
                 a single GPU, you would want to use cuDF.''')
        , (33, 9.26, np.datetime64('2020-10-15T10:58:02'), np.timedelta64(35558,'s'), 'O', 'D', 'parallel'
            , '''If you want to distribute your workflow across multiple GPUs or have more data than you can fit 
                 in memory on a single GPU you would want to use Dask-cuDF''')
        , (42, 4.21, np.datetime64('2020-10-01T10:02:23'), np.timedelta64(20480,'s'), 'U', 'C', 'GPUs'
            , 'BlazingSQL provides a high-performance distributed SQL engine in Python')
        , (36, 3.01, np.datetime64('2020-09-30T14:36:26'), np.timedelta64(24409,'s'), 'T', 'D', None
            , 'BlazingSQL is built on the RAPIDS GPU data science ecosystem')
        , (38, 6.44, np.datetime64('2020-10-10T08:34:36'), np.timedelta64(90171,'s'), 'X', 'B', 'csv'
            , 'BlazingSQL lets you ETL raw data directly into GPU memory as a GPU DataFrame (GDF)')
        , (17, 5.28, np.datetime64('2020-10-09T08:34:40'), np.timedelta64(30532,'s'), 'P', 'D', 'dataframes'
            , 'Dask is a flexible library for parallel computing in Python')
        , (10, 8.28, np.datetime64('2020-10-03T03:31:21'), np.timedelta64(23552,'s'), 'W', 'B', 'python'
            , None)
    ]
    , columns = ['num', 'float', 'datetime', 'timedelta', 'char', 'category', 'word', 'string']
)
cudf_df['category'] = cudf_df['category'].astype('category')

# %% [markdown]
# ---
#
# # Transforming
#
# ---

# %% [markdown]
# ## <span style="color:blue">DataFrame</span>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.apply_rows()

# %%
# pandas
def pandas_regression(a, b, A_coeff, B_coeff, constant):
    return A_coeff * a + B_coeff * b + constant

pandas_df['output'] = pandas_df.apply(
    lambda row: pandas_regression(
        row['num']
        , row['float']
        , A_coeff=0.21
        , B_coeff=-2.82
        , constant=3.43
    ), axis=1)
pandas_df
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
def cudf_regression(a, b, output, A_coeff, B_coeff, constant):
    for i, (aa, bb) in enumerate(zip(a,b)):
        output[i] = A_coeff * aa + B_coeff * bb + constant
        
cudf_df.apply_rows(
    cudf_regression
    , incols = {'num': 'a', 'float': 'b'}
    , outcols = {'output': np.float64}
    , kwargs = {'A_coeff': 0.21, 'B_coeff': -2.82, 'constant': 3.43}
)
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               <NA> -17.8196

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.drop()

# %%
# pandas
pandas_df.drop(1)
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.drop(1)
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        <NA>
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %%
# pandas
pandas_df.drop(range(1,7))
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.drop(range(1,7))
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %%
# pandas
pandas_df.drop('word', axis=1)
# Out:
#    num  float            datetime       timedelta char category  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D
# 1   11   4.21                 NaT             NaT    A        D
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.drop('word', axis=1)
# Out:
#    num  float             datetime        timedelta char category  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1   11   4.21                 <NA>             <NA>    A        D
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %%
# pandas
pandas_df.drop(['word', 'category'], axis=1)
# Out:
#    num  float            datetime       timedelta char  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C
# 1   11   4.21                 NaT             NaT    A
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.drop(['word', 'category'], axis=1)
# Out:
#    num  float             datetime        timedelta char  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C
# 1   11   4.21                 <NA>             <NA>    A
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.dropna()

# %%
# pandas
pandas_df.dropna()
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896

# %%
# cudf
cudf_df.dropna()
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...

# %%
# pandas
pandas_df.dropna(subset=['datetime'])
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.dropna(subset=['datetime'])
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        <NA>
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %%
# pandas
pandas_df.dropna(how='all')
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.dropna(how='all')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %%
# pandas
pandas_df.dropna(axis=1)
# Out:
#    num  float char category   output
# 0   39   6.88    C        D  -7.7816
# 1   11   4.21    A        D  -6.1322
# 2   31   4.71    U        D  -3.3422
# 3   40   0.93    P        B   9.2074
# 4   33   9.26    O        D -15.7532
# 5   42   4.21    U        C   0.3778
# 6   36   3.01    T        D   2.5018
# 7   38   6.44    X        B  -6.7508
# 8   17   5.28    P        D  -7.8896
# 9   10   8.28    W        B -17.8196

# %%
# cudf
cudf_df.dropna(axis=1)
# Out:
#    num  float char category
# 0   39   6.88    C        D
# 1   11   4.21    A        D
# 2   31   4.71    U        D
# 3   40   0.93    P        B
# 4   33   9.26    O        D
# 5   42   4.21    U        C
# 6   36   3.01    T        D
# 7   38   6.44    X        B
# 8   17   5.28    P        D
# 9   10   8.28    W        B

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.fillna()

# %%
# pandas
pandas_df.fillna({'num': 1})
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.fillna({'num': 1})
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.join()

# %%
# pandas
pandas_categories = pd.DataFrame([
    ('B', 'cuDF')
    , ('C', 'BlazingSQL')
    , ('D', 'Dask')
], columns=['cat', 'name'])

pandas_df.join(pandas_categories)
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output  cat        name
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816    B        cuDF
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322    C  BlazingSQL
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422    D        Dask
# 3  If your workflow is fast enough on a single GP...   9.2074  NaN         NaN
# 4  If you want to distribute your workflow across... -15.7532  NaN         NaN
# 5  BlazingSQL provides a high-performance distrib...   0.3778  NaN         NaN
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018  NaN         NaN
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508  NaN         NaN
# 8  Dask is a flexible library for parallel comput...  -7.8896  NaN         NaN
# 9                                               None -17.8196  NaN         NaN

# %%
# cudf
cudf_categories = cudf.DataFrame([
    ('B', 'cuDF')
    , ('C', 'BlazingSQL')
    , ('D', 'Dask')
], columns=['cat', 'name'])

cudf_df.join(cudf_categories)
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string   cat        name
# 0  RAPIDS.ai is a suite of open-source libraries ...     B        cuDF
# 1  cuDF is a Python GPU DataFrame (built on the A...     C  BlazingSQL
# 2  cuDF allows for loading, joining, aggregating,...     D        Dask
# 3  If your workflow is fast enough on a single GP...  <NA>        <NA>
# 4  If you want to distribute your workflow across...  <NA>        <NA>
# 5  BlazingSQL provides a high-performance distrib...  <NA>        <NA>
# 6  BlazingSQL is built on the RAPIDS GPU data sci...  <NA>        <NA>
# 7  BlazingSQL lets you ETL raw data directly into...  <NA>        <NA>
# 8  Dask is a flexible library for parallel comput...  <NA>        <NA>
# 9                                               <NA>  <NA>        <NA>

# %%
# pandas
pandas_df.join(pandas_categories, lsuffix='_l', rsuffix='_r', how='left')
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output  cat        name
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816    B        cuDF
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322    C  BlazingSQL
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422    D        Dask
# 3  If your workflow is fast enough on a single GP...   9.2074  NaN         NaN
# 4  If you want to distribute your workflow across... -15.7532  NaN         NaN
# 5  BlazingSQL provides a high-performance distrib...   0.3778  NaN         NaN
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018  NaN         NaN
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508  NaN         NaN
# 8  Dask is a flexible library for parallel comput...  -7.8896  NaN         NaN
# 9                                               None -17.8196  NaN         NaN

# %%
# cudf
cudf_df.join(cudf_categories, lsuffix='_l', rsuffix='_r', how='left')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string   cat        name
# 0  RAPIDS.ai is a suite of open-source libraries ...     B        cuDF
# 1  cuDF is a Python GPU DataFrame (built on the A...     C  BlazingSQL
# 2  cuDF allows for loading, joining, aggregating,...     D        Dask
# 3  If your workflow is fast enough on a single GP...  <NA>        <NA>
# 4  If you want to distribute your workflow across...  <NA>        <NA>
# 5  BlazingSQL provides a high-performance distrib...  <NA>        <NA>
# 6  BlazingSQL is built on the RAPIDS GPU data sci...  <NA>        <NA>
# 7  BlazingSQL lets you ETL raw data directly into...  <NA>        <NA>
# 8  Dask is a flexible library for parallel comput...  <NA>        <NA>
# 9                                               <NA>  <NA>        <NA>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.merge()

# %%
# pandas
pandas_categories = pd.DataFrame([
    ('B', 'cuDF')
    , ('C', 'BlazingSQL')
    , ('D', 'Dask')
], columns=['category', 'name'])

# %%
# cudf
cudf_categories = cudf.DataFrame([
    ('B', 'cuDF')
    , ('C', 'BlazingSQL')
    , ('D', 'Dask')
], columns=['category', 'name'])

# %%
# pandas
pandas_df.merge(pandas_categories, on='category')
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 4   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 5   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 6   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
# 9   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
#
#                                               string   output        name
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816        Dask
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322        Dask
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422        Dask
# 3  If you want to distribute your workflow across... -15.7532        Dask
# 4  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018        Dask
# 5  Dask is a flexible library for parallel comput...  -7.8896        Dask
# 6  If your workflow is fast enough on a single GP...   9.2074        cuDF
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508        cuDF
# 8                                               None -17.8196        cuDF
# 9  BlazingSQL provides a high-performance distrib...   0.3778  BlazingSQL

# %%
cudf_df.merge(cudf_categories, on='category')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string        name
# 0  RAPIDS.ai is a suite of open-source libraries ...        Dask
# 1  cuDF is a Python GPU DataFrame (built on the A...        Dask
# 2  cuDF allows for loading, joining, aggregating,...        Dask
# 3  If your workflow is fast enough on a single GP...        cuDF
# 4  If you want to distribute your workflow across...        Dask
# 5  BlazingSQL provides a high-performance distrib...  BlazingSQL
# 6  BlazingSQL is built on the RAPIDS GPU data sci...        Dask
# 7  BlazingSQL lets you ETL raw data directly into...        cuDF
# 8  Dask is a flexible library for parallel comput...        Dask
# 9                                               <NA>        cuDF

# %%
# pandas
pandas_df.merge(pandas_categories, on='category', how='left')
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output        name
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816        Dask
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322        Dask
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422        Dask
# 3  If your workflow is fast enough on a single GP...   9.2074        cuDF
# 4  If you want to distribute your workflow across... -15.7532        Dask
# 5  BlazingSQL provides a high-performance distrib...   0.3778  BlazingSQL
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018        Dask
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508        cuDF
# 8  Dask is a flexible library for parallel comput...  -7.8896        Dask
# 9                                               None -17.8196        cuDF

# %%
# cudf
cudf_df['category'] = cudf_df['category'].astype('str')
cudf_df.merge(cudf_categories, on='category', how='left')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string        name
# 0  RAPIDS.ai is a suite of open-source libraries ...        Dask
# 1  cuDF is a Python GPU DataFrame (built on the A...        Dask
# 2  cuDF allows for loading, joining, aggregating,...        Dask
# 3  If your workflow is fast enough on a single GP...        cuDF
# 4  If you want to distribute your workflow across...        Dask
# 5  BlazingSQL provides a high-performance distrib...  BlazingSQL
# 6  BlazingSQL is built on the RAPIDS GPU data sci...        Dask
# 7  BlazingSQL lets you ETL raw data directly into...        cuDF
# 8  Dask is a flexible library for parallel comput...        Dask
# 9                                               <NA>        cuDF

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rename()

# %%
# pandas
pandas_df.rename({0: 100})
# Out:
#      num  float            datetime       timedelta char category        word  \
# 100   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1     11   4.21                 NaT             NaT    A        D        cuDF
# 2     31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3     40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4     33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5     42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6     36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7     38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8     17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9     10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                                 string   output
# 100  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1    cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2    cuDF allows for loading, joining, aggregating,...  -3.3422
# 3    If your workflow is fast enough on a single GP...   9.2074
# 4    If you want to distribute your workflow across... -15.7532
# 5    BlazingSQL provides a high-performance distrib...   0.3778
# 6    BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7    BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8    Dask is a flexible library for parallel comput...  -7.8896
# 9                                                 None -17.8196

# %%
# cudf
cudf_df.rename({0: 100})
# Out:
#      num  float             datetime        timedelta char category  \
# 100   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1     11   4.21                 <NA>             <NA>    A        D
# 2     31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3     40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4     33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5     42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6     36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7     38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8     17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9     10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#            word                                             string
# 100        data  RAPIDS.ai is a suite of open-source libraries ...
# 1          cuDF  cuDF is a Python GPU DataFrame (built on the A...
# 2        memory  cuDF allows for loading, joining, aggregating,...
# 3       tabular  If your workflow is fast enough on a single GP...
# 4      parallel  If you want to distribute your workflow across...
# 5          GPUs  BlazingSQL provides a high-performance distrib...
# 6          <NA>  BlazingSQL is built on the RAPIDS GPU data sci...
# 7           csv  BlazingSQL lets you ETL raw data directly into...
# 8    dataframes  Dask is a flexible library for parallel comput...
# 9        python                                               <NA>

# %%
# pandas
pandas_df.rename({'num': 'numbers'}, axis=1)
# Out:
#    numbers  float            datetime       timedelta char category  \
# 0       39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D
# 1       11   4.21                 NaT             NaT    A        D
# 2       31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D
# 3       40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B
# 4       33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D
# 5       42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C
# 6       36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D
# 7       38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B
# 8       17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D
# 9       10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B
#
#          word                                             string   output
# 0        data  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1        cuDF  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2      memory  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3     tabular  If your workflow is fast enough on a single GP...   9.2074
# 4    parallel  If you want to distribute your workflow across... -15.7532
# 5        GPUs  BlazingSQL provides a high-performance distrib...   0.3778
# 6        None  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7         csv  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  dataframes  Dask is a flexible library for parallel comput...  -7.8896
# 9      python                                               None -17.8196

# %%
# cudf
cudf_df.rename({'num': 'numbers'}, axis=1)
# Out:
#    numbers  float             datetime        timedelta char category  \
# 0       39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1       11   4.21                 <NA>             <NA>    A        D
# 2       31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3       40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4       33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5       42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6       36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7       38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8       17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9       10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#          word                                             string
# 0        data  RAPIDS.ai is a suite of open-source libraries ...
# 1        cuDF  cuDF is a Python GPU DataFrame (built on the A...
# 2      memory  cuDF allows for loading, joining, aggregating,...
# 3     tabular  If your workflow is fast enough on a single GP...
# 4    parallel  If you want to distribute your workflow across...
# 5        GPUs  BlazingSQL provides a high-performance distrib...
# 6        <NA>  BlazingSQL is built on the RAPIDS GPU data sci...
# 7         csv  BlazingSQL lets you ETL raw data directly into...
# 8  dataframes  Dask is a flexible library for parallel comput...
# 9      python                                               <NA>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.reset_index()

# %%
# pandas
pandas_df.reset_index()
# Out:
#    index  num  float            datetime       timedelta char category  \
# 0      0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D
# 1      1   11   4.21                 NaT             NaT    A        D
# 2      2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D
# 3      3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B
# 4      4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D
# 5      5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C
# 6      6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D
# 7      7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B
# 8      8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D
# 9      9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B
#
#          word                                             string   output
# 0        data  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1        cuDF  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2      memory  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3     tabular  If your workflow is fast enough on a single GP...   9.2074
# 4    parallel  If you want to distribute your workflow across... -15.7532
# 5        GPUs  BlazingSQL provides a high-performance distrib...   0.3778
# 6        None  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7         csv  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  dataframes  Dask is a flexible library for parallel comput...  -7.8896
# 9      python                                               None -17.8196

# %%
# cudf
cudf_df.reset_index()
# Out:
#    index  num  float             datetime        timedelta char category  \
# 0      0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1      1   11   4.21                 <NA>             <NA>    A        D
# 2      2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3      3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4      4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5      5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6      6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7      7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8      8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9      9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#          word                                             string
# 0        data  RAPIDS.ai is a suite of open-source libraries ...
# 1        cuDF  cuDF is a Python GPU DataFrame (built on the A...
# 2      memory  cuDF allows for loading, joining, aggregating,...
# 3     tabular  If your workflow is fast enough on a single GP...
# 4    parallel  If you want to distribute your workflow across...
# 5        GPUs  BlazingSQL provides a high-performance distrib...
# 6        <NA>  BlazingSQL is built on the RAPIDS GPU data sci...
# 7         csv  BlazingSQL lets you ETL raw data directly into...
# 8  dataframes  Dask is a flexible library for parallel comput...
# 9      python                                               <NA>

# %%
# pandas
pandas_df.reset_index(drop=True)
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 1   11   4.21                 NaT             NaT    A        D        cuDF
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        None
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string   output
# 0  RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# 1  cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# 2  cuDF allows for loading, joining, aggregating,...  -3.3422
# 3  If your workflow is fast enough on a single GP...   9.2074
# 4  If you want to distribute your workflow across... -15.7532
# 5  BlazingSQL provides a high-performance distrib...   0.3778
# 6  BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# 7  BlazingSQL lets you ETL raw data directly into...  -6.7508
# 8  Dask is a flexible library for parallel comput...  -7.8896
# 9                                               None -17.8196

# %%
# cudf
cudf_df.reset_index(drop=True)
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# 6  BlazingSQL is built on the RAPIDS GPU data sci...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.set_index()

# %%
# pandas
pandas_df.set_index('category')
# Out:
#           num  float            datetime       timedelta char        word  \
# category
# D          39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        data
# D          11   4.21                 NaT             NaT    A        cuDF
# D          31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U      memory
# B          40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P     tabular
# D          33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O    parallel
# C          42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        GPUs
# D          36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        None
# B          38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X         csv
# D          17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P  dataframes
# B          10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W      python
#
#                                                      string   output
# category
# D         RAPIDS.ai is a suite of open-source libraries ...  -7.7816
# D         cuDF is a Python GPU DataFrame (built on the A...  -6.1322
# D         cuDF allows for loading, joining, aggregating,...  -3.3422
# B         If your workflow is fast enough on a single GP...   9.2074
# D         If you want to distribute your workflow across... -15.7532
# C         BlazingSQL provides a high-performance distrib...   0.3778
# D         BlazingSQL is built on the RAPIDS GPU data sci...   2.5018
# B         BlazingSQL lets you ETL raw data directly into...  -6.7508
# D         Dask is a flexible library for parallel comput...  -7.8896
# B                                                      None -17.8196

# %%
# cudf
cudf_df.set_index('category')
# Out:
#           num  float             datetime        timedelta char        word  \
# category
# D          39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        data
# D          11   4.21                 <NA>             <NA>    A        cuDF
# D          31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U      memory
# B          40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P     tabular
# D          33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O    parallel
# C          42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        GPUs
# D          36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        <NA>
# B          38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X         csv
# D          17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P  dataframes
# B          10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W      python
#
#                                                      string
# category
# D         RAPIDS.ai is a suite of open-source libraries ...
# D         cuDF is a Python GPU DataFrame (built on the A...
# D         cuDF allows for loading, joining, aggregating,...
# B         If your workflow is fast enough on a single GP...
# D         If you want to distribute your workflow across...
# C         BlazingSQL provides a high-performance distrib...
# D         BlazingSQL is built on the RAPIDS GPU data sci...
# B         BlazingSQL lets you ETL raw data directly into...
# D         Dask is a flexible library for parallel comput...
# B                                                      <NA>

# %%
# pandas
pandas_df.set_index('category', drop=False)
# Out:
#           num  float            datetime       timedelta char category  \
# category
# D          39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D
# D          11   4.21                 NaT             NaT    A        D
# D          31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D
# B          40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B
# D          33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D
# C          42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C
# D          36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D
# B          38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B
# D          17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D
# B          10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B
#
#                 word                                             string  \
# category
# D               data  RAPIDS.ai is a suite of open-source libraries ...
# D               cuDF  cuDF is a Python GPU DataFrame (built on the A...
# D             memory  cuDF allows for loading, joining, aggregating,...
# B            tabular  If your workflow is fast enough on a single GP...
# D           parallel  If you want to distribute your workflow across...
# C               GPUs  BlazingSQL provides a high-performance distrib...
# D               None  BlazingSQL is built on the RAPIDS GPU data sci...
# B                csv  BlazingSQL lets you ETL raw data directly into...
# D         dataframes  Dask is a flexible library for parallel comput...
# B             python                                               None
#
#            output
# category
# D         -7.7816
# D         -6.1322
# D         -3.3422
# B          9.2074
# D        -15.7532
# C          0.3778
# D          2.5018
# B         -6.7508
# D         -7.8896
# B        -17.8196

# %%
# cudf
cudf_df.set_index('category', drop=False)
# Out:
#           num  float             datetime        timedelta char category  \
# category
# D          39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# D          11   4.21                 <NA>             <NA>    A        D
# D          31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# B          40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# D          33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# C          42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# D          36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# B          38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# D          17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# B          10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#                 word                                             string
# category
# D               data  RAPIDS.ai is a suite of open-source libraries ...
# D               cuDF  cuDF is a Python GPU DataFrame (built on the A...
# D             memory  cuDF allows for loading, joining, aggregating,...
# B            tabular  If your workflow is fast enough on a single GP...
# D           parallel  If you want to distribute your workflow across...
# C               GPUs  BlazingSQL provides a high-performance distrib...
# D               <NA>  BlazingSQL is built on the RAPIDS GPU data sci...
# B                csv  BlazingSQL lets you ETL raw data directly into...
# D         dataframes  Dask is a flexible library for parallel comput...
# B             python                                               <NA>
